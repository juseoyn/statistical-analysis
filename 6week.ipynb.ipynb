# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %precision 3
# %matplotlib inline

# %%
df = pd.read_csv('../ju/data/ch4_scores400.csv')
scores = np.array(df['score'])
scores[:10]
# Out:
# array([76, 55, 80, 80, 74, 61, 81, 76, 23, 80])

# %%
np.random.choice([1,2,3],3)
#복원추출
# Out:
# array([2, 3, 3])

# %%
np.random.choice([1,2,3],3,replace=False)
#비복원추출
# Out:
# array([2, 3, 1])

# %%
np.random.seed(0)
np.random.choice([1,2,3],3)
#시드를 0으로 하는 무작위 추출은 매번 동일한 결과
# Out:
# array([1, 2, 1])

# %%
np.random.seed(0)
sample = np.random.choice(scores,20)

sample.mean()
# Out:
# 70.400

# %%
#무작위 추측은 실행할 떄마다 결과 달라져서 표본평균도 매번 달라짐
np.random.choice([1,2,3],3)
# Out:
# array([3, 1, 2])

# %%
np.random.choice([1,2,3],3,replace=False)
# Out:
# array([1, 3, 2])

# %%
np.random.seed(0)
np.random.choice([1,2,3],3)
# Out:
# array([1, 2, 1])

# %%
np.random.seed(0)
sample = np.random.choice(scores,20)

sample.mean()
# Out:
# 70.400

# %%
scores.mean()
# Out:
# 69.530

# %%
for i in range(5):
    sample = np.random.choice(scores,20)
    print(f'{i+1}번째 무작위 추출로 얻은 표본평균', sample.mean())
# Out:
# 1번째 무작위 추출로 얻은 표본평균 72.45
# 2번째 무작위 추출로 얻은 표본평균 63.7
# 3번째 무작위 추출로 얻은 표본평균 66.05
# 4번째 무작위 추출로 얻은 표본평균 71.7
# 5번째 무작위 추출로 얻은 표본평균 74.15

# %%
dice = [1,2,3,4,5,6]
prob = [1/21, 2/21, 3/21, 4/21, 5/21, 6/21]

# %%
np.random.choice(dice, p=prob)
# Out:
# np.int64(1)

# %%
num_trial = 100
sample=np.random.choice(dice, num_trial, p=prob)
sample
# Out:
# array([4, 6, 4, 5, 5, 6, 6, 3, 5, 6, 5, 6, 6, 2, 3, 1, 6, 5, 6, 3, 4, 5,
#        3, 4, 3, 5, 5, 4, 4, 6, 4, 6, 5, 6, 5, 4, 6, 2, 6, 4, 5, 3, 4, 6,
#        5, 5, 5, 3, 4, 5, 4, 4, 6, 4, 4, 6, 6, 2, 2, 4, 5, 1, 6, 4, 3, 2,
#        2, 6, 3, 5, 4, 2, 4, 4, 6, 6, 1, 5, 3, 6, 6, 4, 2, 1, 6, 4, 4, 2,
#        4, 1, 3, 6, 6, 6, 4, 5, 4, 3, 3, 4])

# %%
freq,_ = np.histogram(sample, bins=6, range=(1,7))
pd.DataFrame({'frequency':freq,
              'relative frequency': freq/num_trial},
             index = pd.Index(np.arange(1,7), name='dice'))
# Out:
#       frequency  relative frequency
# dice
# 1             5                0.05
# 2             9                0.09
# 3            13                0.13
# 4            27                0.27
# 5            19                0.19
# 6            27                0.27

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=6, range=(1, 7), density=True, rwidth=0.8)
#실제의 확률분포를 가로선으로 표시
ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
#막대 그래프의 [1.5, 2.5, ..., 6.5]에 눈금을 표시
ax.set_xticks(np.linspace(1.5, 6.5, 6))
#주사위 눈의 값은 [1, 2, 3, 4, 5, 6]
ax.set_xticklabels(np.arange(1, 7))
ax.set_xlabel('dice')
ax.set_ylabel('relative frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 fig = plt.figure(figsize=(10, 6))
#       2 ax = fig.add_subplot(111)
# ----> 3 ax.hist(sample, bins=6, range=(1, 7), density=True, rwidth=0.8)
#       4 #실제의 확률분포를 가로선으로 표시
#       5 ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
#
# NameError: name 'sample' is not defined

# %%
num_trial = 10000
sample = np.random.choice(dice, size=num_trial, p=prob)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=6, range=(1, 7), density=True, rwidth=0.8)
ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
ax.set_xticks(np.linspace(1.5, 6.5, 6))
ax.set_xticklabels(
np.arange(1, 7))
ax.set_xlabel('dice')
ax.set_ylabel('relative frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 num_trial = 10000
# ----> 2 sample = np.random.choice(dice, size=num_trial, p=prob)
#       4 fig = plt.figure(figsize=(10, 6))
#       5 ax = fig.add_subplot(111)
#
# NameError: name 'dice' is not defined

# %% [markdown]
# fig = plt.figure(figsize=(10, 6))
# ax = fig.add_subplot(111)
# ax.hist(scores, bins=100, range=(0, 100), density=True)
# ax.set_xlim(20, 100)
# ax.set_ylim(0, 0.042)
# ax.set_xlabel('score')
# ax.set_ylabel('relative frequency')
# plt.show()

# %%
np.random.choice(scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 np.random.choice(scores)
#
# NameError: name 'np' is not defined

# %%
sample = np.random.choice(scores, 10000)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=100, range=(0, 100), density=True)
ax.set_xlim(20, 100)
ax.set_ylim(0, 0.042)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sample = np.random.choice(scores, 10000)
#       3 fig = plt.figure(figsize=(10, 6))
#       4 ax = fig.add_subplot(111)
#
# NameError: name 'np' is not defined

# %%
sample_means = [np.random.choice(scores, 20).mean()
                for _ in range(10000)]

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample_means, bins=100, range=(0, 100), density=True)
#모평균을 세로선으로 표시
ax.vlines(np.mean(scores), 0, 1, 'gray')
ax.set_xlim(50, 90)
ax.set_ylim(0, 0.13)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sample_means = [np.random.choice(scores, 20).mean()
#       2                 for _ in range(10000)]
#       4 fig = plt.figure(figsize=(10, 6))
#       5 ax = fig.add_subplot(111)
#
# NameError: name 'np' is not defined
